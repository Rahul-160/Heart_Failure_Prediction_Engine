# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/framingham.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
df.drop('education', axis = 1, inplace = True)

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
df['cigsPerDay'] = df['cigsPerDay'].fillna(df['cigsPerDay'].mode()[0])
df['BPMeds'] = df['BPMeds'].fillna(df['BPMeds'].mode()[0])
df['totChol'] = df['totChol'].fillna(df['totChol'].mode()[0])
df['BMI'] = df['BMI'].fillna(df['BMI'].mean())
df['heartRate'] = df['heartRate'].fillna(df['heartRate'].mode()[0])
df['glucose'] = df['glucose'].fillna(df['glucose'].mode()[0])

# %%
df.isna().sum()
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4235     0   48              1        20.0     0.0                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
X = df.iloc[:, :-1]
X
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4235     0   48              1        20.0     0.0                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# ...

# %%
Y = df.iloc[:, -1]
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4235    0
# 4236    0
# 4237    0
# 4238    0
# 4239    0
# Name: TenYearCHD, Length: 4240, dtype: int64

# %%
Y.value_counts()
# Out:
# 0    3596
# 1     644
# Name: TenYearCHD, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
os = RandomOverSampler()
X_os, Y_os = os.fit_resample(X, Y)
Y_os.value_counts()
# Out:
# 0    3596
# 1    3596
# Name: TenYearCHD, dtype: int64

# %%
df.columns
# Out:
# Index(['male', 'age', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0         0.0     0.0                0
# 1     0   46              0         0.0     0.0                0
# 2     1   48              1        20.0     0.0                0
# 3     0   61              1        30.0     0.0                0
# 4     0   46              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
len(df)
# Out:
# 4240

# %%
len(df.columns)
# Out:
# 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   currentSmoker    4240 non-null   int64
#  3   cigsPerDay       4240 non-null   float64
#  4   BPMeds           4240 non-null   float64
#  5   prevalentStroke  4240 non-null   int64
#  6   prevalentHyp     4240 non-null   int64
#  7   diabetes         4240 non-null   int64
#  8   totChol          4240 non-null   float64
#  9   sysBP            4240 non-null   float64
#  10  diaBP            4240 non-null   float64
#  11  BMI              4240 non-null   float64
#  12  heartRate        4240 non-null   float64
#  13  glucose          4240 non-null   float64
#  14  TenYearCHD       4240 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 497.0 KB

# %%
df.describe()
# Out:
#               male          age  currentSmoker   cigsPerDay       BPMeds  \
# count  4240.000000  4240.000000    4240.000000  4240.000000  4240.000000
# mean      0.429245    49.580189       0.494104     8.944340     0.029245
# std       0.495027     8.572942       0.500024    11.904777     0.168513
# min       0.000000    32.000000       0.000000     0.000000     0.000000
# 25%       0.000000    42.000000       0.000000     0.000000     0.000000
# 50%       0.000000    49.000000       0.000000     0.000000     0.000000
# 75%       1.000000    56.000000       1.000000    20.000000     0.000000
# max       1.000000    70.000000       1.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol        sysBP  \
# count      4240.000000   4240.000000  4240.000000  4240.000000  4240.000000
# mean          0.005896      0.310613     0.025708   236.738443   132.354599
# std           0.076569      0.462799     0.158280    44.328954    22.033300
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_os_scaled = scaler.fit_transform(X_os)
X_os_scaled
# Out:
# array([[1.        , 0.18421053, 0.        , ..., 0.27702375, 0.36363636,
#         0.10451977],
#        [0.        , 0.36842105, 0.        , ..., 0.31968008, 0.51515152,
#         0.10169492],
#        [1.        , 0.42105263, 1.        , ..., 0.23751818, 0.31313131,
#         0.08474576],
#        ...,
#        [1.        , 0.47368421, 1.        , ..., 0.19413476, 0.31313131,
#         0.0819209 ],
#        [1.        , 0.78947368, 0.        , ..., 0.30174503, 0.12121212,
#         0.12146893],
#        [1.        , 0.89473684, 0.        , ..., 0.08603975, 0.2020202 ,
#         0.16384181]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_os_scaled, Y_os, test_size = 0.3, random_state = 1)

# %%
X_train.shape, Y_train.shape
# Out:
# ((5034, 14), (5034,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((2158, 14), (2158,))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
kne = KNeighborsClassifier()
svc = SVC()
gau = GaussianNB()
dec = DecisionTreeClassifier()
ran = RandomForestClassifier(n_estimators = 200, random_state = 1, criterion = 'entropy', max_depth = 5)
ada = AdaBoostClassifier(random_state = 1)
xgb = XGBClassifier(max_depth = 25, random_state = 1, base_score = 0.8)
model = [kne, svc, gau, dec, ran, ada, xgb]
for model in model:
  print(model)
  model.fit(X_train, Y_train)
  Y_pred = model.predict(X_test)
  print(classification_report(Y_test, Y_pred))
  print(ConfusionMatrixDisplay.from_predictions(Y_test, Y_pred))
# Out:
# KNeighborsClassifier()
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77      1074
#            1       0.75      0.87      0.81      1084
#
#     accuracy                           0.79      2158
#    macro avg       0.80      0.79      0.79      2158
# weighted avg       0.80      0.79      0.79      2158
#
# ...
# SVC()
#               precision    recall  f1-score   support
#
#            0       0.67      0.68      0.67      1074
#            1       0.68      0.67      0.67      1084
#
#     accuracy                           0.67      2158
#    macro avg       0.67      0.67      0.67      2158
# weighted avg       0.67      0.67      0.67      2158
#
# ...
# GaussianNB()
#               precision    recall  f1-score   support
#
#            0       0.56      0.90      0.69      1074
#            1       0.76      0.31      0.44      1084
#
#     accuracy                           0.60      2158
# ...

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors' : [3, 5, 7, 9], 'weights' : ['uniform', 'distance'],
          'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']}
clf = GridSearchCV(kne, params, cv = 10, scoring = 'accuracy')
clf.fit(X_train, Y_train)
print(clf.best_params_)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'distance'}

# %%
knn1 = KNeighborsClassifier(algorithm = 'auto', n_neighbors = 3, weights = 'distance')
knn1.fit(X_train, Y_train)
Y_pred = knn1.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.76      0.86      1074
#            1       0.81      1.00      0.89      1084
#
#     accuracy                           0.88      2158
#    macro avg       0.90      0.88      0.88      2158
# weighted avg       0.90      0.88      0.88      2158

# %%
from sklearn.model_selection import GridSearchCV
params1 = {'gamma' : ['scale', 'auto'],
          'C' : [1.0, 2.0, 3.0, 4.0]}
clf = GridSearchCV(svc, params1, cv = 10, scoring = 'accuracy')
clf.fit(X_train, Y_train)
print(clf.best_params_)
# Out:
# {'C': 4.0, 'gamma': 'scale'}

# %%
svc1 = SVC(C= 4.0, class_weight = 'balanced', gamma = 'scale')
svc1.fit(X_train, Y_train)
Y_pred = svc1.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70      1074
#            1       0.70      0.69      0.70      1084
#
#     accuracy                           0.70      2158
#    macro avg       0.70      0.70      0.70      2158
# weighted avg       0.70      0.70      0.70      2158

# %%
import numpy as np
nb_classifier = GaussianNB()
params2 = {'var_smoothing': np.logspace(0,-9, num=100)}
clf = GridSearchCV(gau,
                   params2,
                 cv = 10,   # use any cross validation technique
                 verbose=1,
                 scoring='accuracy')
clf.fit(X_train, Y_train)

print(clf.best_params_)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# {'var_smoothing': 1.0}

# %%
gau1 = GaussianNB(var_smoothing = 0.012328467394420659)
gau1.fit(X_train, Y_train)
Y_pred = gau1.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.90      0.69      1074
#            1       0.76      0.30      0.43      1084
#
#     accuracy                           0.60      2158
#    macro avg       0.66      0.60      0.56      2158
# weighted avg       0.66      0.60      0.56      2158

# %%
from sklearn.model_selection import GridSearchCV
params = {'criterion' : ['gini', 'entropy', 'log_loss'], 'splitter' : ['best', 'random'],
          'random_state' : [1, 2, 3, 4], 'max_depth' : [1, 2, 3, 4]}
clf = GridSearchCV(dec, params, cv = 10, scoring = 'accuracy')
clf.fit(X_train, Y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'random_state': 1, 'splitter': 'best'}

# %%
dec1 = DecisionTreeClassifier(criterion = 'entropy',  random_state = 1, splitter = 'best')
dec1.fit(X_train, Y_train)
Y_pred = dec1.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88      1074
#            1       0.83      0.99      0.90      1084
#
#     accuracy                           0.89      2158
#    macro avg       0.91      0.89      0.89      2158
# weighted avg       0.91      0.89      0.89      2158
